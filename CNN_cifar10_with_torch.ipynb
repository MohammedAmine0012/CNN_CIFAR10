# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# Image Classification (CIFAR-10) by CNN
#
# Training the CNN model by SGD with Dropout and Weight Decay.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
# load CIFAR-10 data
train_dataset = dsets.CIFAR10('./data',
                         train=True,
                         download=True,
                         transform=transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Normalize(
                                [0.5, 0.5, 0.5],  # RGB 
                                [0.5, 0.5, 0.5]   # RGB 
                                )
                         ]))
test_dataset = dsets.CIFAR10('./data',
                         train=False,
                         download=True,
                         transform=transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Normalize(
                                 [0.5, 0.5, 0.5],  # RGB 
                                 [0.5, 0.5, 0.5]  # RGB 
                             )
                         ]))

#print(len(train_Dataset))

train_dataset, valid_dataset = torch.utils.data.random_split(  
      train_dataset,   
      [40000, 10000])  

print('train_dataset = ', len(train_dataset))
print('valid_dataset = ', len(valid_dataset))
print('test_dataset = ', len(test_dataset))
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.3MB/s]
# train_dataset =  40000
# valid_dataset =  10000
# test_dataset =  10000

# %%
# Set up DataLoader
batch=128

train_loader = torch.utils.data.DataLoader(
        dataset=train_dataset,
        batch_size=batch,
        shuffle=True
    )

valid_loader = torch.utils.data.DataLoader(
        dataset=valid_dataset,
        batch_size=batch,
        shuffle=True
    )

test_loader = torch.utils.data.DataLoader(
        dataset=test_dataset,
        batch_size=batch,
        shuffle=True
    )

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class EnhancedCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(EnhancedCNN, self).__init__()

        # First convolutional block
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv1_2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.bn1_2 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.3)

        # Second convolutional block
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv2_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.bn2_2 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.4)

        # Third convolutional block
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv3_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.bn3_2 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout3 = nn.Dropout(0.5)

        # Fully connected layers
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.bn_fc1 = nn.BatchNorm1d(256)
        self.dropout_fc1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        # First block
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn1_2(self.conv1_2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)

        # Second block
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = self.pool2(x)
        x = self.dropout2(x)

        # Third block
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn3_2(self.conv3_2(x)))
        x = self.pool3(x)
        x = self.dropout3(x)

        # Flatten and feed to fully connected layers
        x = x.view(-1, 128 * 4 * 4)
        x = F.relu(self.bn_fc1(self.fc1(x)))
        x = self.dropout_fc1(x)
        x = self.fc2(x)

        return x

# Instantiate the model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Create and move model to device
net = EnhancedCNN(num_classes=10)
net = net.to(device)

# Print model architecture
print('Network architecture for CNN:\n', net)
# Out:
# Using device: cuda
# Network architecture for CNN:
#  EnhancedCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1_2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1_2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.4, inplace=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=2048, out_features=256, bias=True)
#   (bn_fc1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout_fc1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
# optimizing
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.001)

# %%
# Define Class names
classes = ('plane', 'car', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck')

# %%
###  training
print ('training start ...')
num_epochs = 100

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0

    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
      
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation
        optimizer.step()  # optimization

    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:
          
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)

    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}'
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Out:
# training start ...
# Epoch [1/100] train Loss: 0.0159, train acc: 0.2369 | val_loss: 0.0161, val_acc: 0.2393
# Epoch [2/100] train Loss: 0.0144, train acc: 0.3271 | val_loss: 0.0146, val_acc: 0.3320
# Epoch [3/100] train Loss: 0.0144, train acc: 0.3491 | val_loss: 0.0146, val_acc: 0.3457
# Epoch [4/100] train Loss: 0.0130, train acc: 0.4177 | val_loss: 0.0133, val_acc: 0.4156
# Epoch [5/100] train Loss: 0.0123, train acc: 0.4531 | val_loss: 0.0126, val_acc: 0.4499
# Epoch [6/100] train Loss: 0.0105, train acc: 0.5111 | val_loss: 0.0108, val_acc: 0.5060
# Epoch [7/100] train Loss: 0.0105, train acc: 0.5206 | val_loss: 0.0107, val_acc: 0.5142
# Epoch [8/100] train Loss: 0.0108, train acc: 0.5178 | val_loss: 0.0111, val_acc: 0.5147
# Epoch [9/100] train Loss: 0.0100, train acc: 0.5424 | val_loss: 0.0103, val_acc: 0.5409
# Epoch [10/100] train Loss: 0.0092, train acc: 0.5751 | val_loss: 0.0096, val_acc: 0.5653
# Epoch [11/100] train Loss: 0.0078, train acc: 0.6415 | val_loss: 0.0083, val_acc: 0.6306
# Epoch [12/100] train Loss: 0.0079, train acc: 0.6362 | val_loss: 0.0083, val_acc: 0.6302
# Epoch [13/100] train Loss: 0.0083, train acc: 0.6221 | val_loss: 0.0087, val_acc: 0.6138
# Epoch [14/100] train Loss: 0.0071, train acc: 0.6700 | val_loss: 0.0075, val_acc: 0.6599
# Epoch [15/100] train Loss: 0.0075, train acc: 0.6574 | val_loss: 0.0079, val_acc: 0.6496
# Epoch [16/100] train Loss: 0.0071, train acc: 0.6799 | val_loss: 0.0075, val_acc: 0.6716
# Epoch [17/100] train Loss: 0.0063, train acc: 0.7106 | val_loss: 0.0068, val_acc: 0.6986
# Epoch [18/100] train Loss: 0.0066, train acc: 0.6987 | val_loss: 0.0071, val_acc: 0.6822
# Epoch [19/100] train Loss: 0.0065, train acc: 0.7032 | val_loss: 0.0069, val_acc: 0.6852
# Epoch [20/100] train Loss: 0.0064, train acc: 0.7100 | val_loss: 0.0069, val_acc: 0.6942
# Epoch [21/100] train Loss: 0.0060, train acc: 0.7253 | val_loss: 0.0065, val_acc: 0.7091
# Epoch [22/100] train Loss: 0.0056, train acc: 0.7412 | val_loss: 0.0062, val_acc: 0.7266
# Epoch [23/100] train Loss: 0.0055, train acc: 0.7487 | val_loss: 0.0061, val_acc: 0.7291
# Epoch [24/100] train Loss: 0.0058, train acc: 0.7355 | val_loss: 0.0064, val_acc: 0.7158
# Epoch [25/100] train Loss: 0.0055, train acc: 0.7453 | val_loss: 0.0062, val_acc: 0.7278
# Epoch [26/100] train Loss: 0.0058, train acc: 0.7391 | val_loss: 0.0065, val_acc: 0.7176
# Epoch [27/100] train Loss: 0.0056, train acc: 0.7463 | val_loss: 0.0062, val_acc: 0.7271
# Epoch [28/100] train Loss: 0.0051, train acc: 0.7659 | val_loss: 0.0057, val_acc: 0.7437
# Epoch [29/100] train Loss: 0.0051, train acc: 0.7691 | val_loss: 0.0058, val_acc: 0.7455
# Epoch [30/100] train Loss: 0.0048, train acc: 0.7774 | val_loss: 0.0056, val_acc: 0.7557
# Epoch [31/100] train Loss: 0.0050, train acc: 0.7734 | val_loss: 0.0057, val_acc: 0.7471
# Epoch [32/100] train Loss: 0.0046, train acc: 0.7901 | val_loss: 0.0053, val_acc: 0.7641
# Epoch [33/100] train Loss: 0.0049, train acc: 0.7764 | val_loss: 0.0057, val_acc: 0.7463
# Epoch [34/100] train Loss: 0.0044, train acc: 0.8002 | val_loss: 0.0052, val_acc: 0.7723
# Epoch [35/100] train Loss: 0.0045, train acc: 0.7946 | val_loss: 0.0053, val_acc: 0.7640
# Epoch [36/100] train Loss: 0.0044, train acc: 0.7994 | val_loss: 0.0052, val_acc: 0.7695
# Epoch [37/100] train Loss: 0.0042, train acc: 0.8079 | val_loss: 0.0050, val_acc: 0.7697
# Epoch [38/100] train Loss: 0.0041, train acc: 0.8126 | val_loss: 0.0050, val_acc: 0.7785
# Epoch [39/100] train Loss: 0.0040, train acc: 0.8163 | val_loss: 0.0049, val_acc: 0.7789
# Epoch [40/100] train Loss: 0.0043, train acc: 0.8046 | val_loss: 0.0052, val_acc: 0.7696
# Epoch [41/100] train Loss: 0.0039, train acc: 0.8232 | val_loss: 0.0048, val_acc: 0.7844
# Epoch [42/100] train Loss: 0.0040, train acc: 0.8192 | val_loss: 0.0050, val_acc: 0.7830
# Epoch [43/100] train Loss: 0.0039, train acc: 0.8254 | val_loss: 0.0048, val_acc: 0.7897
# Epoch [44/100] train Loss: 0.0039, train acc: 0.8214 | val_loss: 0.0049, val_acc: 0.7850
# Epoch [45/100] train Loss: 0.0036, train acc: 0.8360 | val_loss: 0.0046, val_acc: 0.7965
# Epoch [46/100] train Loss: 0.0039, train acc: 0.8210 | val_loss: 0.0050, val_acc: 0.7808
# Epoch [47/100] train Loss: 0.0036, train acc: 0.8343 | val_loss: 0.0047, val_acc: 0.7930
# Epoch [48/100] train Loss: 0.0040, train acc: 0.8189 | val_loss: 0.0051, val_acc: 0.7804
# Epoch [49/100] train Loss: 0.0038, train acc: 0.8266 | val_loss: 0.0049, val_acc: 0.7828
# Epoch [50/100] train Loss: 0.0035, train acc: 0.8434 | val_loss: 0.0046, val_acc: 0.7999
# Epoch [51/100] train Loss: 0.0038, train acc: 0.8258 | val_loss: 0.0050, val_acc: 0.7851
# Epoch [52/100] train Loss: 0.0034, train acc: 0.8485 | val_loss: 0.0045, val_acc: 0.8003
# Epoch [53/100] train Loss: 0.0033, train acc: 0.8536 | val_loss: 0.0044, val_acc: 0.8049
# Epoch [54/100] train Loss: 0.0034, train acc: 0.8460 | val_loss: 0.0046, val_acc: 0.8045
# Epoch [55/100] train Loss: 0.0033, train acc: 0.8469 | val_loss: 0.0045, val_acc: 0.8024
# Epoch [56/100] train Loss: 0.0032, train acc: 0.8547 | val_loss: 0.0043, val_acc: 0.8076
# Epoch [57/100] train Loss: 0.0032, train acc: 0.8548 | val_loss: 0.0044, val_acc: 0.8090
# Epoch [58/100] train Loss: 0.0032, train acc: 0.8584 | val_loss: 0.0044, val_acc: 0.8106
# Epoch [59/100] train Loss: 0.0031, train acc: 0.8605 | val_loss: 0.0043, val_acc: 0.8083
# Epoch [60/100] train Loss: 0.0031, train acc: 0.8596 | val_loss: 0.0044, val_acc: 0.8057
# Epoch [61/100] train Loss: 0.0033, train acc: 0.8544 | val_loss: 0.0045, val_acc: 0.8029
# Epoch [62/100] train Loss: 0.0028, train acc: 0.8717 | val_loss: 0.0042, val_acc: 0.8211
# Epoch [63/100] train Loss: 0.0029, train acc: 0.8694 | val_loss: 0.0042, val_acc: 0.8159
# Epoch [64/100] train Loss: 0.0029, train acc: 0.8686 | val_loss: 0.0042, val_acc: 0.8149
# Epoch [65/100] train Loss: 0.0028, train acc: 0.8738 | val_loss: 0.0041, val_acc: 0.8177
# Epoch [66/100] train Loss: 0.0028, train acc: 0.8729 | val_loss: 0.0042, val_acc: 0.8178
# Epoch [67/100] train Loss: 0.0027, train acc: 0.8802 | val_loss: 0.0041, val_acc: 0.8257
# Epoch [68/100] train Loss: 0.0027, train acc: 0.8808 | val_loss: 0.0041, val_acc: 0.8220
# Epoch [69/100] train Loss: 0.0027, train acc: 0.8769 | val_loss: 0.0042, val_acc: 0.8190
# Epoch [70/100] train Loss: 0.0025, train acc: 0.8853 | val_loss: 0.0039, val_acc: 0.8284
# Epoch [71/100] train Loss: 0.0028, train acc: 0.8760 | val_loss: 0.0042, val_acc: 0.8182
# Epoch [72/100] train Loss: 0.0026, train acc: 0.8812 | val_loss: 0.0040, val_acc: 0.8252
# Epoch [73/100] train Loss: 0.0025, train acc: 0.8878 | val_loss: 0.0040, val_acc: 0.8282
# Epoch [74/100] train Loss: 0.0026, train acc: 0.8841 | val_loss: 0.0040, val_acc: 0.8246
# Epoch [75/100] train Loss: 0.0025, train acc: 0.8882 | val_loss: 0.0040, val_acc: 0.8234
# Epoch [76/100] train Loss: 0.0028, train acc: 0.8774 | val_loss: 0.0043, val_acc: 0.8134
# Epoch [77/100] train Loss: 0.0025, train acc: 0.8862 | val_loss: 0.0042, val_acc: 0.8221
# Epoch [78/100] train Loss: 0.0022, train acc: 0.9041 | val_loss: 0.0037, val_acc: 0.8370
# Epoch [79/100] train Loss: 0.0024, train acc: 0.8912 | val_loss: 0.0040, val_acc: 0.8267
# Epoch [80/100] train Loss: 0.0025, train acc: 0.8906 | val_loss: 0.0040, val_acc: 0.8281
# Epoch [81/100] train Loss: 0.0021, train acc: 0.9072 | val_loss: 0.0037, val_acc: 0.8371
# Epoch [82/100] train Loss: 0.0022, train acc: 0.9021 | val_loss: 0.0039, val_acc: 0.8354
# Epoch [83/100] train Loss: 0.0022, train acc: 0.9015 | val_loss: 0.0038, val_acc: 0.8336
# Epoch [84/100] train Loss: 0.0021, train acc: 0.9063 | val_loss: 0.0038, val_acc: 0.8392
# Epoch [85/100] train Loss: 0.0021, train acc: 0.9095 | val_loss: 0.0037, val_acc: 0.8385
# Epoch [86/100] train Loss: 0.0022, train acc: 0.9036 | val_loss: 0.0039, val_acc: 0.8302
# Epoch [87/100] train Loss: 0.0021, train acc: 0.9091 | val_loss: 0.0038, val_acc: 0.8361
# Epoch [88/100] train Loss: 0.0022, train acc: 0.9013 | val_loss: 0.0039, val_acc: 0.8282
# Epoch [89/100] train Loss: 0.0021, train acc: 0.9031 | val_loss: 0.0038, val_acc: 0.8299
# Epoch [90/100] train Loss: 0.0021, train acc: 0.9075 | val_loss: 0.0038, val_acc: 0.8334
# Epoch [91/100] train Loss: 0.0020, train acc: 0.9099 | val_loss: 0.0038, val_acc: 0.8359
# Epoch [92/100] train Loss: 0.0021, train acc: 0.9074 | val_loss: 0.0038, val_acc: 0.8344
# Epoch [93/100] train Loss: 0.0021, train acc: 0.9092 | val_loss: 0.0039, val_acc: 0.8365
# Epoch [94/100] train Loss: 0.0019, train acc: 0.9189 | val_loss: 0.0037, val_acc: 0.8404
# Epoch [95/100] train Loss: 0.0020, train acc: 0.9129 | val_loss: 0.0038, val_acc: 0.8375
# Epoch [96/100] train Loss: 0.0018, train acc: 0.9220 | val_loss: 0.0038, val_acc: 0.8414
# Epoch [97/100] train Loss: 0.0018, train acc: 0.9214 | val_loss: 0.0037, val_acc: 0.8406
# Epoch [98/100] train Loss: 0.0021, train acc: 0.9048 | val_loss: 0.0040, val_acc: 0.8273
# Epoch [99/100] train Loss: 0.0019, train acc: 0.9188 | val_loss: 0.0038, val_acc: 0.8425
# Epoch [100/100] train Loss: 0.0018, train acc: 0.9225 | val_loss: 0.0037, val_acc: 0.8405

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total))

import os


# Create the 'trained_models' directory if it doesn't exist
os.makedirs('./trained_models', exist_ok=True)

# Save model weights using torch.save
# This saves the entire model state, including weights and biases.
torch.save(net.state_dict(), './trained_models/CNN_cifar10_tf.weights.pth')
print("hhhh")
# You can load the weights later using:
# net.load_state_dict(torch.load('./trained_models/CNN_cifar10_tf.weights.pth'))
# Out:
# test_accuracy: 84.52 %
# hhhh

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_cifar10_loss.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.0, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_cifar10_acc.png')
plt.show()
